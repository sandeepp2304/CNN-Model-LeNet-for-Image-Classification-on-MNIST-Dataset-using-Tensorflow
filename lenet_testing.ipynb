# %%
# Importing the packages

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import load_model

import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# loading the model
lenet_model = load_model('/content/gdrive/MyDrive/lenet_model.h5')

# %%
lenet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  average_pooling2d (AverageP  (None, 12, 12, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2416
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 120)               30840
#
#  flatten_1 (Flatten)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# ...
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
# importing the mnist dataset from the tensorflow package

# loading the dataset into trin and as test 
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# first set 28 x 28 is the number of rows and columns
rows, cols = 28, 28

#to visualize a single image at the index 4444 (9 is in the dataset)
image_index = 4444
plt.imshow(x_test[image_index].reshape(28, 28),cmap='Greys')

#To predict the output using the lenet model built

pred = lenet_model.predict(x_test[image_index].reshape(1, rows, cols, 1))
print(pred.argmax())
print("Result fot the given image {0}".format(pred.argmax()))
# Out:
# 9
# Result fot the given image 9
